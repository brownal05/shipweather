# %%
import json
import pandas as pd

file = "bulk.json"

# %%
data = pd.read_json(file)
length = len(data)

# %%
wind = []
rain_ttl = data["rain"]
date = data["dt_iso"]

#pd.DataFrame("Wind")

# %%
rain_df = pd.DataFrame({"Rainfall" : rain_ttl,
            "Date": date})
rain_df.dropna()
# Out:
#                           Rainfall                           Date
# 0                     {'3h': 2.06}  2015-06-12 01:00:00 +0000 UTC
# 1                     {'3h': 0.67}  2015-06-12 23:00:00 +0000 UTC
# 2                     {'3h': 0.67}  2015-06-13 01:00:00 +0000 UTC
# 3                     {'3h': 0.84}  2015-06-13 02:00:00 +0000 UTC
# 6                   {'3h': 5.2175}  2015-06-15 01:00:00 +0000 UTC
# 7                     {'3h': 1.16}  2015-06-19 23:00:00 +0000 UTC
# 10                  {'3h': 0.6925}  2015-06-22 23:00:00 +0000 UTC
# 11                    {'3h': 1.22}  2015-06-24 09:00:00 +0000 UTC
# 12     {'3h': 0.35000000000000003}  2015-06-24 11:00:00 +0000 UTC
# 13     {'3h': 0.35000000000000003}  2015-06-24 12:00:00 +0000 UTC
# 14     {'3h': 0.35000000000000003}  2015-06-24 13:00:00 +0000 UTC
# 19                  {'3h': 3.0625}  2015-06-24 20:00:00 +0000 UTC
# 20                  {'3h': 3.0625}  2015-06-24 21:00:00 +0000 UTC
# ...
